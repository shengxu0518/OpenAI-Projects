# %%
import numpy as np
import copy
import os
import pickle
import sys
from reinforce_lib import func_approx_library as funclib

# %load_ext autoreload
# %autoreload 2

class QLearner():
    # load in simulator, initialize global variables
    def __init__(self,simulator,savename,**kwargs):
        # make simulator global
        self.simulator = simulator
        
        # Q learn params
        self.explore_val = 1
        self.explore_decay = 0.99
        self.num_episodes = 500        
        self.gamma = 1
        
        if "gamma" in kwargs:   
            self.gamma = args['gamma']
        if 'explore_val' in kwargs:
            self.explore_val = kwargs['explore_val']
        if 'explore_decay' in kwargs:
            self.explore_decay = kwargs['explore_decay']
        if 'num_episodes' in kwargs:
            self.num_episodes = kwargs['num_episodes']
            
        # other training variables
        self.num_actions = self.simulator.action_space.n
        state = self.simulator.reset()    
        self.state_dim = np.size(state)
        self.training_reward = []
        
        # setup memory params
        self.memory_length = 10     # length of memory replay (in episodes)
        self.episode_update = 1     # when to update (in episodes)
        self.memory = []
        if 'memory_length' in kwargs:
            self.memory_length = kwargs['memory_length']
        if 'episode_update' in kwargs:
            self.episode_update = kwargs['episode_update']
            
        ### initialize logs ###
        # create text file for training log
        self.logname = 'training_logs/' + savename + '.txt'
        self.reward_logname = 'reward_logs/' + savename + '.txt'
        self.weight_name = 'saved_model_weights/' + savename + '.pkl' 
        self.model_name = 'models/' + savename + '.json'

        self.init_log(self.logname)
        self.init_log(self.reward_logname)
        self.init_log(self.weight_name)
        self.init_log(self.model_name)
     
    ##### logging functions #####
    def init_log(self,logname):
        # delete log if old version exists
        if os.path.exists(logname): 
            os.remove(logname)
            
    def update_log(self,logname,update):
        if type(update) == str:
            logfile = open(logname, "a")
            logfile.write(update)
            logfile.close() 
        else:
            weights = []
            if os.path.exists(logname):
                with open(logname,'rb') as rfp: 
                    weights = pickle.load(rfp)
            weights.append(update)

            with open(logname,'wb') as wfp:
                pickle.dump(weights, wfp)
    
    ##### functions for creating / updating Q #####
    def initialize_Q(self,**kwargs):
        # default parameters for network
        layer_sizes = [10,10]      # two hidden layers, 10 units each, by default
        activation = 'relu'
        if 'layer_sizes' in kwargs:
            layer_sizes = kwargs['layer_sizes']
        if 'activation' in kwargs:
            activation = kwargs['activation']

        # default parameters for optimizer - reset by hand
        loss = 'mse'
        self.lr = 10**(-2)
        if 'alpha' in kwargs:
            self.lr = kwargs['alpha']

        # input / output sizes of network
        input_dim = self.state_dim
        output_dim = self.num_actions
    
        # setup network
        layer_sizes.insert(0,input_dim)
        layer_sizes.append(output_dim)

        # setup architecture, choose cost, and setup architecture
        self.model = funclib.super_setup.Setup()
        self.model.choose_cost(name = 'least_squares')
        self.model.choose_features(layer_sizes = layer_sizes,activation = activation)
            
        # initialize Q
        self.Q = self.model.predict

    # update Q function
    def update_Q(self):
        # generate q_values based on most recent Q
        q_vals = []
        states = []
        for i in range(len(self.memory)):    
            # get episode_data
            episode_data = self.memory[i]
            
            # loop over episode data and create input/output pairs
            for j in range(len(episode_data)):
                # get next sample of episode
                sample = episode_data[j]
            
                # strip sample for parts
                state = sample[0]
                next_state = sample[1]
                action = sample[2]
                reward = sample[3]
                done = sample[4]

                ### for cartpole only - check if done, and alter reward to improve learning ###
                done,reward = self.check_done(done,reward)

                # compute and store q value
                q = reward 
                if done == False:
                    qs = self.Q(next_state.T)
                    q += self.gamma*np.max(qs)

                # clamp all other models to their current values for this input/output pair
                q_update = self.Q(state.T).flatten()
                q_update[action] = q
                q_vals.append(q_update)
                states.append(state.T)
            
        # convert lists to numpy arrays for regressor
        s_in = np.array(states).T
        q_vals = np.array(q_vals).T
        s_in = s_in[0,:,:]
                            
        # take descent step
        self.model.fit(s_in,q_vals,algo = 'RMSprop',max_its = 1,alpha = self.lr,verbose = False)
        
        # update Q based on regressor updates
        self.Q = self.model.predict
        
    ##### functions for adjusting replay memory #####
    # update memory - add sample to list, remove oldest samples 
    def update_memory(self,episode_data):
        # add most recent trial data to memory
        self.memory.append(episode_data)

        # clip memory if it gets too long    
        num_episodes = len(self.memory)
        if num_episodes >= self.memory_length:    
            num_delete = num_episodes - self.memory_length
            self.memory[:num_delete] = []
    
    ##### Q Learning functionality #####
    # state normalizer
    def state_normalizer(self,states):
        states = np.array(states)[np.newaxis,:]
        return states
    
    # choose next action
    def choose_action(self,state):
        # pick action at random
        p = np.random.rand(1)   
        action = np.random.randint(self.num_actions)
            
        # pick action based on exploiting
        qs = self.Q(state.T) 
        if p > self.explore_val:
            action = np.argmax(qs)
        return action

    # special function to check done
    def check_done(self,done,reward):
        if done == True:
            reward = -100
        return done,reward
    
    # main training function
    def train(self,**kwargs):        
        ### start main Q-learning loop ###
        for n in range(self.num_episodes): 
            # pick this episode's starting position - randomly initialize from f_system
            state = self.simulator.reset()    
            state = self.state_normalizer(state)
            total_episode_reward = 0
            done = False
            
            # get out exploit parameter for this episode
            if self.explore_val > 0.01:
                self.explore_val *= self.explore_decay
                    
            # run episode
            step = 0
            episode_data = []
            while done == False and step < 500:    
                # choose next action
                action = self.choose_action(state)
    
                # transition to next state, get associated reward
                next_state,reward,done,info = self.simulator.step(action)  
                next_state = self.state_normalizer(next_state)
                
                # store data for transition after episode ends
                episode_data.append([state,next_state,action,reward,done])

                # update total reward from this episode
                total_episode_reward+=reward
                state = copy.deepcopy(next_state)
                step+=1
                
            # update memory with this episode's data
            self.update_memory(episode_data)
            
            # update Q function
            if np.mod(n,self.episode_update) == 0:
                self.update_Q()  
                  
            # print out update 
            update = 'training episode ' + str(n+1) +  ' of ' + str(self.num_episodes) + ' complete, ' +  ' explore val = ' + str(np.round(self.explore_val,3)) + ', episode reward = ' + str(np.round(total_episode_reward,2)) 

            self.update_log(self.logname,update + '\n')
            print (update)

            update = str(total_episode_reward) + '\n'
            self.update_log(self.reward_logname,update)

            ### store this episode's computation time and training reward history
            self.training_reward.append(total_episode_reward)

            # save latest weights from this episode 
            update = self.model.weight_history[-1]
            self.update_log(self.weight_name,update)
            
        ### save weights ###
        update = 'q-learning algorithm complete'
        self.update_log(self.logname,update + '\n')
        print (update)

# %% [markdown]
# # Run test

# %%
# imports
import gym

# savename
savename = 'cartpole_experiment_1'

# initialize simulator
simulator = gym.make('CartPole-v1') 

# initialize Q Learn process
num_episodes = 1500
explore_decay = 0.995
explore_val = 1

# initialize memory
episode_update = 1
memory_length = 10

# load into instance of learner
demo = QLearner(simulator,savename,num_episodes=num_episodes,explore_decay=explore_decay,explore_val=explore_val,memory_length=memory_length,episode_update=episode_update)

# initialize Q function
layer_sizes = [50,50]
alpha = 10**(-2)
activation = 'maxout'
demo.initialize_Q(layer_sizes=layer_sizes,alpha=alpha,activation=activation)
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.

# %%
demo.train()
# Out:
# training episode 1 of 1500 complete,  explore val = 0.995, episode reward = 27.0
# training episode 2 of 1500 complete,  explore val = 0.99, episode reward = 30.0
# training episode 3 of 1500 complete,  explore val = 0.985, episode reward = 19.0
# training episode 4 of 1500 complete,  explore val = 0.98, episode reward = 31.0
# training episode 5 of 1500 complete,  explore val = 0.975, episode reward = 14.0
# training episode 6 of 1500 complete,  explore val = 0.97, episode reward = 26.0
# training episode 7 of 1500 complete,  explore val = 0.966, episode reward = 20.0
# training episode 8 of 1500 complete,  explore val = 0.961, episode reward = 22.0
# training episode 9 of 1500 complete,  explore val = 0.956, episode reward = 39.0
# training episode 10 of 1500 complete,  explore val = 0.951, episode reward = 28.0
# training episode 11 of 1500 complete,  explore val = 0.946, episode reward = 32.0
# training episode 12 of 1500 complete,  explore val = 0.942, episode reward = 13.0
# training episode 13 of 1500 complete,  explore val = 0.937, episode reward = 17.0
# training episode 14 of 1500 complete,  explore val = 0.932, episode reward = 31.0
# training episode 15 of 1500 complete,  explore val = 0.928, episode reward = 18.0
# training episode 16 of 1500 complete,  explore val = 0.923, episode reward = 45.0
# training episode 17 of 1500 complete,  explore val = 0.918, episode reward = 17.0
# training episode 18 of 1500 complete,  explore val = 0.914, episode reward = 34.0
# training episode 19 of 1500 complete,  explore val = 0.909, episode reward = 19.0
# training episode 20 of 1500 complete,  explore val = 0.905, episode reward = 11.0
# training episode 21 of 1500 complete,  explore val = 0.9, episode reward = 24.0
# training episode 22 of 1500 complete,  explore val = 0.896, episode reward = 26.0
# training episode 23 of 1500 complete,  explore val = 0.891, episode reward = 18.0
# training episode 24 of 1500 complete,  explore val = 0.887, episode reward = 12.0
# training episode 25 of 1500 complete,  explore val = 0.882, episode reward = 34.0
# training episode 26 of 1500 complete,  explore val = 0.878, episode reward = 27.0
# training episode 27 of 1500 complete,  explore val = 0.873, episode reward = 15.0
# training episode 28 of 1500 complete,  explore val = 0.869, episode reward = 15.0
# training episode 29 of 1500 complete,  explore val = 0.865, episode reward = 23.0
# training episode 30 of 1500 complete,  explore val = 0.86, episode reward = 15.0
# training episode 31 of 1500 complete,  explore val = 0.856, episode reward = 31.0
# training episode 32 of 1500 complete,  explore val = 0.852, episode reward = 16.0
# training episode 33 of 1500 complete,  explore val = 0.848, episode reward = 16.0
# training episode 34 of 1500 complete,  explore val = 0.843, episode reward = 26.0
# training episode 35 of 1500 complete,  explore val = 0.839, episode reward = 21.0
# training episode 36 of 1500 complete,  explore val = 0.835, episode reward = 22.0
# training episode 37 of 1500 complete,  explore val = 0.831, episode reward = 17.0
# training episode 38 of 1500 complete,  explore val = 0.827, episode reward = 12.0
# training episode 39 of 1500 complete,  explore val = 0.822, episode reward = 15.0
# training episode 40 of 1500 complete,  explore val = 0.818, episode reward = 12.0
# training episode 41 of 1500 complete,  explore val = 0.814, episode reward = 22.0
# training episode 42 of 1500 complete,  explore val = 0.81, episode reward = 16.0
# training episode 43 of 1500 complete,  explore val = 0.806, episode reward = 27.0
# training episode 44 of 1500 complete,  explore val = 0.802, episode reward = 22.0
# training episode 45 of 1500 complete,  explore val = 0.798, episode reward = 15.0
# training episode 46 of 1500 complete,  explore val = 0.794, episode reward = 16.0
# training episode 47 of 1500 complete,  explore val = 0.79, episode reward = 34.0
# training episode 48 of 1500 complete,  explore val = 0.786, episode reward = 17.0
# training episode 49 of 1500 complete,  explore val = 0.782, episode reward = 19.0
# training episode 50 of 1500 complete,  explore val = 0.778, episode reward = 56.0
# training episode 51 of 1500 complete,  explore val = 0.774, episode reward = 14.0
# training episode 52 of 1500 complete,  explore val = 0.771, episode reward = 30.0
# training episode 53 of 1500 complete,  explore val = 0.767, episode reward = 28.0
# training episode 54 of 1500 complete,  explore val = 0.763, episode reward = 22.0
# training episode 55 of 1500 complete,  explore val = 0.759, episode reward = 46.0
# training episode 56 of 1500 complete,  explore val = 0.755, episode reward = 27.0
# training episode 57 of 1500 complete,  explore val = 0.751, episode reward = 10.0
# training episode 58 of 1500 complete,  explore val = 0.748, episode reward = 14.0
# training episode 59 of 1500 complete,  explore val = 0.744, episode reward = 40.0
# training episode 60 of 1500 complete,  explore val = 0.74, episode reward = 12.0
# training episode 61 of 1500 complete,  explore val = 0.737, episode reward = 19.0
# training episode 62 of 1500 complete,  explore val = 0.733, episode reward = 28.0
# training episode 63 of 1500 complete,  explore val = 0.729, episode reward = 26.0
# training episode 64 of 1500 complete,  explore val = 0.726, episode reward = 57.0
# training episode 65 of 1500 complete,  explore val = 0.722, episode reward = 35.0
# training episode 66 of 1500 complete,  explore val = 0.718, episode reward = 19.0
# training episode 67 of 1500 complete,  explore val = 0.715, episode reward = 44.0
# training episode 68 of 1500 complete,  explore val = 0.711, episode reward = 22.0
# training episode 69 of 1500 complete,  explore val = 0.708, episode reward = 28.0
# training episode 70 of 1500 complete,  explore val = 0.704, episode reward = 18.0
# training episode 71 of 1500 complete,  explore val = 0.701, episode reward = 12.0
# training episode 72 of 1500 complete,  explore val = 0.697, episode reward = 31.0
# training episode 73 of 1500 complete,  explore val = 0.694, episode reward = 21.0
# training episode 74 of 1500 complete,  explore val = 0.69, episode reward = 40.0
# training episode 75 of 1500 complete,  explore val = 0.687, episode reward = 47.0
# training episode 76 of 1500 complete,  explore val = 0.683, episode reward = 35.0
# training episode 77 of 1500 complete,  explore val = 0.68, episode reward = 49.0
# training episode 78 of 1500 complete,  explore val = 0.676, episode reward = 20.0
# training episode 79 of 1500 complete,  explore val = 0.673, episode reward = 24.0
# training episode 80 of 1500 complete,  explore val = 0.67, episode reward = 16.0
# training episode 81 of 1500 complete,  explore val = 0.666, episode reward = 53.0
# training episode 82 of 1500 complete,  explore val = 0.663, episode reward = 42.0
# training episode 83 of 1500 complete,  explore val = 0.66, episode reward = 23.0
# training episode 84 of 1500 complete,  explore val = 0.656, episode reward = 22.0
# training episode 85 of 1500 complete,  explore val = 0.653, episode reward = 23.0
# training episode 86 of 1500 complete,  explore val = 0.65, episode reward = 51.0
# training episode 87 of 1500 complete,  explore val = 0.647, episode reward = 51.0
# training episode 88 of 1500 complete,  explore val = 0.643, episode reward = 24.0
# training episode 89 of 1500 complete,  explore val = 0.64, episode reward = 14.0
# training episode 90 of 1500 complete,  explore val = 0.637, episode reward = 49.0
# training episode 91 of 1500 complete,  explore val = 0.634, episode reward = 40.0
# training episode 92 of 1500 complete,  explore val = 0.631, episode reward = 40.0
# training episode 93 of 1500 complete,  explore val = 0.627, episode reward = 59.0
# training episode 94 of 1500 complete,  explore val = 0.624, episode reward = 39.0
# training episode 95 of 1500 complete,  explore val = 0.621, episode reward = 42.0
# training episode 96 of 1500 complete,  explore val = 0.618, episode reward = 104.0
# training episode 97 of 1500 complete,  explore val = 0.615, episode reward = 83.0
# training episode 98 of 1500 complete,  explore val = 0.612, episode reward = 51.0
# training episode 99 of 1500 complete,  explore val = 0.609, episode reward = 21.0
# training episode 100 of 1500 complete,  explore val = 0.606, episode reward = 43.0
# training episode 101 of 1500 complete,  explore val = 0.603, episode reward = 10.0
# training episode 102 of 1500 complete,  explore val = 0.6, episode reward = 239.0
# training episode 103 of 1500 complete,  explore val = 0.597, episode reward = 37.0
# training episode 104 of 1500 complete,  explore val = 0.594, episode reward = 99.0
# training episode 105 of 1500 complete,  explore val = 0.591, episode reward = 51.0
# training episode 106 of 1500 complete,  explore val = 0.588, episode reward = 55.0
# training episode 107 of 1500 complete,  explore val = 0.585, episode reward = 123.0
# training episode 108 of 1500 complete,  explore val = 0.582, episode reward = 53.0
# training episode 109 of 1500 complete,  explore val = 0.579, episode reward = 31.0
# training episode 110 of 1500 complete,  explore val = 0.576, episode reward = 47.0
# training episode 111 of 1500 complete,  explore val = 0.573, episode reward = 69.0
# training episode 112 of 1500 complete,  explore val = 0.57, episode reward = 63.0
# training episode 113 of 1500 complete,  explore val = 0.568, episode reward = 48.0
# training episode 114 of 1500 complete,  explore val = 0.565, episode reward = 70.0
# training episode 115 of 1500 complete,  explore val = 0.562, episode reward = 42.0
# training episode 116 of 1500 complete,  explore val = 0.559, episode reward = 57.0
# training episode 117 of 1500 complete,  explore val = 0.556, episode reward = 28.0
# training episode 118 of 1500 complete,  explore val = 0.554, episode reward = 106.0
# training episode 119 of 1500 complete,  explore val = 0.551, episode reward = 30.0
# training episode 120 of 1500 complete,  explore val = 0.548, episode reward = 23.0
# training episode 121 of 1500 complete,  explore val = 0.545, episode reward = 43.0
# training episode 122 of 1500 complete,  explore val = 0.543, episode reward = 45.0
# training episode 123 of 1500 complete,  explore val = 0.54, episode reward = 29.0
# training episode 124 of 1500 complete,  explore val = 0.537, episode reward = 127.0
# training episode 125 of 1500 complete,  explore val = 0.534, episode reward = 23.0
# training episode 126 of 1500 complete,  explore val = 0.532, episode reward = 44.0
# training episode 127 of 1500 complete,  explore val = 0.529, episode reward = 182.0
# training episode 128 of 1500 complete,  explore val = 0.526, episode reward = 30.0
# training episode 129 of 1500 complete,  explore val = 0.524, episode reward = 34.0
# training episode 130 of 1500 complete,  explore val = 0.521, episode reward = 48.0
# training episode 131 of 1500 complete,  explore val = 0.519, episode reward = 138.0
# training episode 132 of 1500 complete,  explore val = 0.516, episode reward = 32.0
# training episode 133 of 1500 complete,  explore val = 0.513, episode reward = 93.0
# training episode 134 of 1500 complete,  explore val = 0.511, episode reward = 50.0
# training episode 135 of 1500 complete,  explore val = 0.508, episode reward = 231.0
# training episode 136 of 1500 complete,  explore val = 0.506, episode reward = 123.0
# training episode 137 of 1500 complete,  explore val = 0.503, episode reward = 63.0
# training episode 138 of 1500 complete,  explore val = 0.501, episode reward = 22.0
# training episode 139 of 1500 complete,  explore val = 0.498, episode reward = 190.0
# training episode 140 of 1500 complete,  explore val = 0.496, episode reward = 78.0
# training episode 141 of 1500 complete,  explore val = 0.493, episode reward = 64.0
# training episode 142 of 1500 complete,  explore val = 0.491, episode reward = 138.0
# training episode 143 of 1500 complete,  explore val = 0.488, episode reward = 108.0
# training episode 144 of 1500 complete,  explore val = 0.486, episode reward = 406.0
# training episode 145 of 1500 complete,  explore val = 0.483, episode reward = 147.0
# training episode 146 of 1500 complete,  explore val = 0.481, episode reward = 47.0
# training episode 147 of 1500 complete,  explore val = 0.479, episode reward = 263.0
# training episode 148 of 1500 complete,  explore val = 0.476, episode reward = 13.0
# training episode 149 of 1500 complete,  explore val = 0.474, episode reward = 135.0
# training episode 150 of 1500 complete,  explore val = 0.471, episode reward = 283.0
# training episode 151 of 1500 complete,  explore val = 0.469, episode reward = 228.0
# training episode 152 of 1500 complete,  explore val = 0.467, episode reward = 197.0
# training episode 153 of 1500 complete,  explore val = 0.464, episode reward = 219.0
# training episode 154 of 1500 complete,  explore val = 0.462, episode reward = 176.0
# training episode 155 of 1500 complete,  explore val = 0.46, episode reward = 107.0
# training episode 156 of 1500 complete,  explore val = 0.458, episode reward = 98.0
# training episode 157 of 1500 complete,  explore val = 0.455, episode reward = 277.0
# training episode 158 of 1500 complete,  explore val = 0.453, episode reward = 293.0
# training episode 159 of 1500 complete,  explore val = 0.451, episode reward = 115.0
# training episode 160 of 1500 complete,  explore val = 0.448, episode reward = 203.0
# training episode 161 of 1500 complete,  explore val = 0.446, episode reward = 151.0
# training episode 162 of 1500 complete,  explore val = 0.444, episode reward = 108.0
# training episode 163 of 1500 complete,  explore val = 0.442, episode reward = 264.0
# training episode 164 of 1500 complete,  explore val = 0.44, episode reward = 111.0
# training episode 165 of 1500 complete,  explore val = 0.437, episode reward = 56.0
# training episode 166 of 1500 complete,  explore val = 0.435, episode reward = 281.0
# training episode 167 of 1500 complete,  explore val = 0.433, episode reward = 157.0
# training episode 168 of 1500 complete,  explore val = 0.431, episode reward = 114.0
# training episode 169 of 1500 complete,  explore val = 0.429, episode reward = 237.0
# training episode 170 of 1500 complete,  explore val = 0.427, episode reward = 151.0
# training episode 171 of 1500 complete,  explore val = 0.424, episode reward = 184.0
# training episode 172 of 1500 complete,  explore val = 0.422, episode reward = 58.0
# training episode 173 of 1500 complete,  explore val = 0.42, episode reward = 241.0
# training episode 174 of 1500 complete,  explore val = 0.418, episode reward = 260.0
# training episode 175 of 1500 complete,  explore val = 0.416, episode reward = 57.0
# training episode 176 of 1500 complete,  explore val = 0.414, episode reward = 88.0
# training episode 177 of 1500 complete,  explore val = 0.412, episode reward = 176.0
# training episode 178 of 1500 complete,  explore val = 0.41, episode reward = 182.0
# training episode 179 of 1500 complete,  explore val = 0.408, episode reward = 89.0
# training episode 180 of 1500 complete,  explore val = 0.406, episode reward = 108.0
# training episode 181 of 1500 complete,  explore val = 0.404, episode reward = 44.0
# training episode 182 of 1500 complete,  explore val = 0.402, episode reward = 49.0
# training episode 183 of 1500 complete,  explore val = 0.4, episode reward = 108.0
# training episode 184 of 1500 complete,  explore val = 0.398, episode reward = 124.0
# training episode 185 of 1500 complete,  explore val = 0.396, episode reward = 185.0
# training episode 186 of 1500 complete,  explore val = 0.394, episode reward = 35.0
# training episode 187 of 1500 complete,  explore val = 0.392, episode reward = 220.0
# training episode 188 of 1500 complete,  explore val = 0.39, episode reward = 121.0
# training episode 189 of 1500 complete,  explore val = 0.388, episode reward = 151.0
# training episode 190 of 1500 complete,  explore val = 0.386, episode reward = 132.0
# training episode 191 of 1500 complete,  explore val = 0.384, episode reward = 228.0
# training episode 192 of 1500 complete,  explore val = 0.382, episode reward = 41.0
# training episode 193 of 1500 complete,  explore val = 0.38, episode reward = 219.0
# training episode 194 of 1500 complete,  explore val = 0.378, episode reward = 325.0
# training episode 195 of 1500 complete,  explore val = 0.376, episode reward = 185.0
# training episode 196 of 1500 complete,  explore val = 0.374, episode reward = 33.0
# training episode 197 of 1500 complete,  explore val = 0.373, episode reward = 195.0
# training episode 198 of 1500 complete,  explore val = 0.371, episode reward = 273.0
# training episode 199 of 1500 complete,  explore val = 0.369, episode reward = 190.0
# training episode 200 of 1500 complete,  explore val = 0.367, episode reward = 153.0
# training episode 201 of 1500 complete,  explore val = 0.365, episode reward = 197.0
# training episode 202 of 1500 complete,  explore val = 0.363, episode reward = 104.0
# training episode 203 of 1500 complete,  explore val = 0.361, episode reward = 103.0
# training episode 204 of 1500 complete,  explore val = 0.36, episode reward = 61.0
# training episode 205 of 1500 complete,  explore val = 0.358, episode reward = 11.0
# training episode 206 of 1500 complete,  explore val = 0.356, episode reward = 109.0
# training episode 207 of 1500 complete,  explore val = 0.354, episode reward = 19.0
# training episode 208 of 1500 complete,  explore val = 0.353, episode reward = 168.0
# training episode 209 of 1500 complete,  explore val = 0.351, episode reward = 23.0
# training episode 210 of 1500 complete,  explore val = 0.349, episode reward = 39.0
# training episode 211 of 1500 complete,  explore val = 0.347, episode reward = 159.0
# training episode 212 of 1500 complete,  explore val = 0.346, episode reward = 111.0
# training episode 213 of 1500 complete,  explore val = 0.344, episode reward = 116.0
# training episode 214 of 1500 complete,  explore val = 0.342, episode reward = 101.0
# training episode 215 of 1500 complete,  explore val = 0.34, episode reward = 492.0
# training episode 216 of 1500 complete,  explore val = 0.339, episode reward = 26.0
# training episode 217 of 1500 complete,  explore val = 0.337, episode reward = 168.0
# training episode 218 of 1500 complete,  explore val = 0.335, episode reward = 22.0
# training episode 219 of 1500 complete,  explore val = 0.334, episode reward = 237.0
# training episode 220 of 1500 complete,  explore val = 0.332, episode reward = 21.0
# training episode 221 of 1500 complete,  explore val = 0.33, episode reward = 264.0
# training episode 222 of 1500 complete,  explore val = 0.329, episode reward = 23.0
# training episode 223 of 1500 complete,  explore val = 0.327, episode reward = 183.0
# training episode 224 of 1500 complete,  explore val = 0.325, episode reward = 17.0
# training episode 225 of 1500 complete,  explore val = 0.324, episode reward = 117.0
# training episode 226 of 1500 complete,  explore val = 0.322, episode reward = 12.0
# training episode 227 of 1500 complete,  explore val = 0.321, episode reward = 65.0
# training episode 228 of 1500 complete,  explore val = 0.319, episode reward = 13.0
# training episode 229 of 1500 complete,  explore val = 0.317, episode reward = 170.0
# training episode 230 of 1500 complete,  explore val = 0.316, episode reward = 28.0
# training episode 231 of 1500 complete,  explore val = 0.314, episode reward = 49.0
# training episode 232 of 1500 complete,  explore val = 0.313, episode reward = 19.0
# training episode 233 of 1500 complete,  explore val = 0.311, episode reward = 24.0
# training episode 234 of 1500 complete,  explore val = 0.309, episode reward = 29.0
# training episode 235 of 1500 complete,  explore val = 0.308, episode reward = 24.0
# training episode 236 of 1500 complete,  explore val = 0.306, episode reward = 112.0
# training episode 237 of 1500 complete,  explore val = 0.305, episode reward = 14.0
# training episode 238 of 1500 complete,  explore val = 0.303, episode reward = 208.0
# training episode 239 of 1500 complete,  explore val = 0.302, episode reward = 15.0
# training episode 240 of 1500 complete,  explore val = 0.3, episode reward = 156.0
# training episode 241 of 1500 complete,  explore val = 0.299, episode reward = 30.0
# training episode 242 of 1500 complete,  explore val = 0.297, episode reward = 36.0
# training episode 243 of 1500 complete,  explore val = 0.296, episode reward = 107.0
# training episode 244 of 1500 complete,  explore val = 0.294, episode reward = 83.0
# training episode 245 of 1500 complete,  explore val = 0.293, episode reward = 95.0
# training episode 246 of 1500 complete,  explore val = 0.291, episode reward = 92.0
# training episode 247 of 1500 complete,  explore val = 0.29, episode reward = 413.0
# training episode 248 of 1500 complete,  explore val = 0.288, episode reward = 20.0
# training episode 249 of 1500 complete,  explore val = 0.287, episode reward = 66.0
# training episode 250 of 1500 complete,  explore val = 0.286, episode reward = 25.0
# training episode 251 of 1500 complete,  explore val = 0.284, episode reward = 81.0
# training episode 252 of 1500 complete,  explore val = 0.283, episode reward = 31.0
# training episode 253 of 1500 complete,  explore val = 0.281, episode reward = 141.0
# training episode 254 of 1500 complete,  explore val = 0.28, episode reward = 83.0
# training episode 255 of 1500 complete,  explore val = 0.279, episode reward = 101.0
# training episode 256 of 1500 complete,  explore val = 0.277, episode reward = 29.0
# training episode 257 of 1500 complete,  explore val = 0.276, episode reward = 15.0
# training episode 258 of 1500 complete,  explore val = 0.274, episode reward = 52.0
# training episode 259 of 1500 complete,  explore val = 0.273, episode reward = 21.0
# training episode 260 of 1500 complete,  explore val = 0.272, episode reward = 17.0
# training episode 261 of 1500 complete,  explore val = 0.27, episode reward = 23.0
# training episode 262 of 1500 complete,  explore val = 0.269, episode reward = 86.0
# training episode 263 of 1500 complete,  explore val = 0.268, episode reward = 31.0
# training episode 264 of 1500 complete,  explore val = 0.266, episode reward = 115.0
# training episode 265 of 1500 complete,  explore val = 0.265, episode reward = 21.0
# training episode 266 of 1500 complete,  explore val = 0.264, episode reward = 166.0
# training episode 267 of 1500 complete,  explore val = 0.262, episode reward = 215.0
# training episode 268 of 1500 complete,  explore val = 0.261, episode reward = 500.0
# training episode 269 of 1500 complete,  explore val = 0.26, episode reward = 22.0
# training episode 270 of 1500 complete,  explore val = 0.258, episode reward = 170.0
# training episode 271 of 1500 complete,  explore val = 0.257, episode reward = 18.0
# training episode 272 of 1500 complete,  explore val = 0.256, episode reward = 183.0
# training episode 273 of 1500 complete,  explore val = 0.255, episode reward = 19.0
# training episode 274 of 1500 complete,  explore val = 0.253, episode reward = 236.0
# training episode 275 of 1500 complete,  explore val = 0.252, episode reward = 15.0
# training episode 276 of 1500 complete,  explore val = 0.251, episode reward = 198.0
# training episode 277 of 1500 complete,  explore val = 0.249, episode reward = 17.0
# training episode 278 of 1500 complete,  explore val = 0.248, episode reward = 199.0
# training episode 279 of 1500 complete,  explore val = 0.247, episode reward = 21.0
# training episode 280 of 1500 complete,  explore val = 0.246, episode reward = 171.0
# training episode 281 of 1500 complete,  explore val = 0.245, episode reward = 27.0
# training episode 282 of 1500 complete,  explore val = 0.243, episode reward = 43.0
# training episode 283 of 1500 complete,  explore val = 0.242, episode reward = 34.0
# training episode 284 of 1500 complete,  explore val = 0.241, episode reward = 23.0
# training episode 285 of 1500 complete,  explore val = 0.24, episode reward = 105.0
# training episode 286 of 1500 complete,  explore val = 0.238, episode reward = 21.0
# training episode 287 of 1500 complete,  explore val = 0.237, episode reward = 249.0
# training episode 288 of 1500 complete,  explore val = 0.236, episode reward = 68.0
# training episode 289 of 1500 complete,  explore val = 0.235, episode reward = 138.0
# training episode 290 of 1500 complete,  explore val = 0.234, episode reward = 22.0
# training episode 291 of 1500 complete,  explore val = 0.233, episode reward = 90.0
# training episode 292 of 1500 complete,  explore val = 0.231, episode reward = 17.0
# training episode 293 of 1500 complete,  explore val = 0.23, episode reward = 58.0
# training episode 294 of 1500 complete,  explore val = 0.229, episode reward = 279.0
# training episode 295 of 1500 complete,  explore val = 0.228, episode reward = 45.0
# training episode 296 of 1500 complete,  explore val = 0.227, episode reward = 258.0
# training episode 297 of 1500 complete,  explore val = 0.226, episode reward = 72.0
# training episode 298 of 1500 complete,  explore val = 0.225, episode reward = 273.0
# training episode 299 of 1500 complete,  explore val = 0.223, episode reward = 53.0
# training episode 300 of 1500 complete,  explore val = 0.222, episode reward = 308.0
# training episode 301 of 1500 complete,  explore val = 0.221, episode reward = 32.0
# training episode 302 of 1500 complete,  explore val = 0.22, episode reward = 247.0
# training episode 303 of 1500 complete,  explore val = 0.219, episode reward = 27.0
# training episode 304 of 1500 complete,  explore val = 0.218, episode reward = 306.0
# training episode 305 of 1500 complete,  explore val = 0.217, episode reward = 22.0
# training episode 306 of 1500 complete,  explore val = 0.216, episode reward = 290.0
# training episode 307 of 1500 complete,  explore val = 0.215, episode reward = 15.0
# training episode 308 of 1500 complete,  explore val = 0.214, episode reward = 308.0
# training episode 309 of 1500 complete,  explore val = 0.212, episode reward = 20.0
# training episode 310 of 1500 complete,  explore val = 0.211, episode reward = 250.0
# training episode 311 of 1500 complete,  explore val = 0.21, episode reward = 17.0
# training episode 312 of 1500 complete,  explore val = 0.209, episode reward = 225.0
# training episode 313 of 1500 complete,  explore val = 0.208, episode reward = 16.0
# training episode 314 of 1500 complete,  explore val = 0.207, episode reward = 199.0
# training episode 315 of 1500 complete,  explore val = 0.206, episode reward = 25.0
# training episode 316 of 1500 complete,  explore val = 0.205, episode reward = 168.0
# training episode 317 of 1500 complete,  explore val = 0.204, episode reward = 17.0
# training episode 318 of 1500 complete,  explore val = 0.203, episode reward = 19.0
# training episode 319 of 1500 complete,  explore val = 0.202, episode reward = 140.0
# training episode 320 of 1500 complete,  explore val = 0.201, episode reward = 13.0
# training episode 321 of 1500 complete,  explore val = 0.2, episode reward = 216.0
# training episode 322 of 1500 complete,  explore val = 0.199, episode reward = 14.0
# training episode 323 of 1500 complete,  explore val = 0.198, episode reward = 500.0
# training episode 324 of 1500 complete,  explore val = 0.197, episode reward = 15.0
# training episode 325 of 1500 complete,  explore val = 0.196, episode reward = 383.0
# training episode 326 of 1500 complete,  explore val = 0.195, episode reward = 12.0
# training episode 327 of 1500 complete,  explore val = 0.194, episode reward = 235.0
# training episode 328 of 1500 complete,  explore val = 0.193, episode reward = 211.0
# training episode 329 of 1500 complete,  explore val = 0.192, episode reward = 18.0
# training episode 330 of 1500 complete,  explore val = 0.191, episode reward = 214.0
# training episode 331 of 1500 complete,  explore val = 0.19, episode reward = 17.0
# training episode 332 of 1500 complete,  explore val = 0.189, episode reward = 397.0
# training episode 333 of 1500 complete,  explore val = 0.188, episode reward = 15.0
# training episode 334 of 1500 complete,  explore val = 0.187, episode reward = 500.0
# training episode 335 of 1500 complete,  explore val = 0.187, episode reward = 12.0
# training episode 336 of 1500 complete,  explore val = 0.186, episode reward = 402.0
# training episode 337 of 1500 complete,  explore val = 0.185, episode reward = 17.0
# training episode 338 of 1500 complete,  explore val = 0.184, episode reward = 398.0
# training episode 339 of 1500 complete,  explore val = 0.183, episode reward = 373.0
# training episode 340 of 1500 complete,  explore val = 0.182, episode reward = 16.0
# training episode 341 of 1500 complete,  explore val = 0.181, episode reward = 183.0
# training episode 342 of 1500 complete,  explore val = 0.18, episode reward = 365.0
# training episode 343 of 1500 complete,  explore val = 0.179, episode reward = 11.0
# training episode 344 of 1500 complete,  explore val = 0.178, episode reward = 268.0
# training episode 345 of 1500 complete,  explore val = 0.177, episode reward = 23.0
# training episode 346 of 1500 complete,  explore val = 0.177, episode reward = 184.0
# training episode 347 of 1500 complete,  explore val = 0.176, episode reward = 14.0
# training episode 348 of 1500 complete,  explore val = 0.175, episode reward = 413.0
# training episode 349 of 1500 complete,  explore val = 0.174, episode reward = 17.0
# training episode 350 of 1500 complete,  explore val = 0.173, episode reward = 433.0
# training episode 351 of 1500 complete,  explore val = 0.172, episode reward = 14.0
# training episode 352 of 1500 complete,  explore val = 0.171, episode reward = 287.0
# training episode 353 of 1500 complete,  explore val = 0.17, episode reward = 274.0
# training episode 354 of 1500 complete,  explore val = 0.17, episode reward = 16.0
# training episode 355 of 1500 complete,  explore val = 0.169, episode reward = 450.0
# training episode 356 of 1500 complete,  explore val = 0.168, episode reward = 11.0
# training episode 357 of 1500 complete,  explore val = 0.167, episode reward = 392.0
# training episode 358 of 1500 complete,  explore val = 0.166, episode reward = 16.0
# training episode 359 of 1500 complete,  explore val = 0.165, episode reward = 500.0
# training episode 360 of 1500 complete,  explore val = 0.165, episode reward = 14.0
# training episode 361 of 1500 complete,  explore val = 0.164, episode reward = 435.0
# training episode 362 of 1500 complete,  explore val = 0.163, episode reward = 15.0
# training episode 363 of 1500 complete,  explore val = 0.162, episode reward = 467.0
# training episode 364 of 1500 complete,  explore val = 0.161, episode reward = 17.0
# training episode 365 of 1500 complete,  explore val = 0.16, episode reward = 370.0
# training episode 366 of 1500 complete,  explore val = 0.16, episode reward = 15.0
# training episode 367 of 1500 complete,  explore val = 0.159, episode reward = 312.0
# training episode 368 of 1500 complete,  explore val = 0.158, episode reward = 19.0
# training episode 369 of 1500 complete,  explore val = 0.157, episode reward = 321.0
# training episode 370 of 1500 complete,  explore val = 0.157, episode reward = 19.0
# training episode 371 of 1500 complete,  explore val = 0.156, episode reward = 341.0
# training episode 372 of 1500 complete,  explore val = 0.155, episode reward = 20.0
# training episode 373 of 1500 complete,  explore val = 0.154, episode reward = 237.0
# training episode 374 of 1500 complete,  explore val = 0.153, episode reward = 14.0
# training episode 375 of 1500 complete,  explore val = 0.153, episode reward = 211.0
# training episode 376 of 1500 complete,  explore val = 0.152, episode reward = 15.0
# training episode 377 of 1500 complete,  explore val = 0.151, episode reward = 262.0
# training episode 378 of 1500 complete,  explore val = 0.15, episode reward = 18.0
# training episode 379 of 1500 complete,  explore val = 0.15, episode reward = 216.0
# training episode 380 of 1500 complete,  explore val = 0.149, episode reward = 11.0
# training episode 381 of 1500 complete,  explore val = 0.148, episode reward = 187.0
# training episode 382 of 1500 complete,  explore val = 0.147, episode reward = 24.0
# training episode 383 of 1500 complete,  explore val = 0.147, episode reward = 172.0
# training episode 384 of 1500 complete,  explore val = 0.146, episode reward = 20.0
# training episode 385 of 1500 complete,  explore val = 0.145, episode reward = 166.0
# training episode 386 of 1500 complete,  explore val = 0.144, episode reward = 102.0
# training episode 387 of 1500 complete,  explore val = 0.144, episode reward = 134.0
# training episode 388 of 1500 complete,  explore val = 0.143, episode reward = 118.0
# training episode 389 of 1500 complete,  explore val = 0.142, episode reward = 109.0
# training episode 390 of 1500 complete,  explore val = 0.142, episode reward = 143.0
# training episode 391 of 1500 complete,  explore val = 0.141, episode reward = 104.0
# training episode 392 of 1500 complete,  explore val = 0.14, episode reward = 173.0
# training episode 393 of 1500 complete,  explore val = 0.139, episode reward = 43.0
# training episode 394 of 1500 complete,  explore val = 0.139, episode reward = 141.0
# training episode 395 of 1500 complete,  explore val = 0.138, episode reward = 123.0
# training episode 396 of 1500 complete,  explore val = 0.137, episode reward = 85.0
# training episode 397 of 1500 complete,  explore val = 0.137, episode reward = 91.0
# training episode 398 of 1500 complete,  explore val = 0.136, episode reward = 95.0
# training episode 399 of 1500 complete,  explore val = 0.135, episode reward = 138.0
# training episode 400 of 1500 complete,  explore val = 0.135, episode reward = 15.0
# training episode 401 of 1500 complete,  explore val = 0.134, episode reward = 182.0
# training episode 402 of 1500 complete,  explore val = 0.133, episode reward = 19.0
# training episode 403 of 1500 complete,  explore val = 0.133, episode reward = 221.0
# training episode 404 of 1500 complete,  explore val = 0.132, episode reward = 14.0
# training episode 405 of 1500 complete,  explore val = 0.131, episode reward = 255.0
# training episode 406 of 1500 complete,  explore val = 0.131, episode reward = 16.0
# training episode 407 of 1500 complete,  explore val = 0.13, episode reward = 500.0
# training episode 408 of 1500 complete,  explore val = 0.129, episode reward = 14.0
# training episode 409 of 1500 complete,  explore val = 0.129, episode reward = 227.0
# training episode 410 of 1500 complete,  explore val = 0.128, episode reward = 15.0
# training episode 411 of 1500 complete,  explore val = 0.127, episode reward = 233.0
# training episode 412 of 1500 complete,  explore val = 0.127, episode reward = 156.0
# training episode 413 of 1500 complete,  explore val = 0.126, episode reward = 97.0
# training episode 414 of 1500 complete,  explore val = 0.126, episode reward = 349.0
# training episode 415 of 1500 complete,  explore val = 0.125, episode reward = 23.0
# training episode 416 of 1500 complete,  explore val = 0.124, episode reward = 279.0
# training episode 417 of 1500 complete,  explore val = 0.124, episode reward = 19.0
# training episode 418 of 1500 complete,  explore val = 0.123, episode reward = 238.0
# training episode 419 of 1500 complete,  explore val = 0.122, episode reward = 17.0
# training episode 420 of 1500 complete,  explore val = 0.122, episode reward = 221.0
# training episode 421 of 1500 complete,  explore val = 0.121, episode reward = 475.0
# training episode 422 of 1500 complete,  explore val = 0.121, episode reward = 21.0
# training episode 423 of 1500 complete,  explore val = 0.12, episode reward = 295.0
# training episode 424 of 1500 complete,  explore val = 0.119, episode reward = 179.0
# training episode 425 of 1500 complete,  explore val = 0.119, episode reward = 78.0
# training episode 426 of 1500 complete,  explore val = 0.118, episode reward = 132.0
# training episode 427 of 1500 complete,  explore val = 0.118, episode reward = 70.0
# training episode 428 of 1500 complete,  explore val = 0.117, episode reward = 146.0
# training episode 429 of 1500 complete,  explore val = 0.116, episode reward = 22.0
# training episode 430 of 1500 complete,  explore val = 0.116, episode reward = 150.0
# training episode 431 of 1500 complete,  explore val = 0.115, episode reward = 18.0
# training episode 432 of 1500 complete,  explore val = 0.115, episode reward = 168.0
# training episode 433 of 1500 complete,  explore val = 0.114, episode reward = 22.0
# training episode 434 of 1500 complete,  explore val = 0.114, episode reward = 166.0
# training episode 435 of 1500 complete,  explore val = 0.113, episode reward = 59.0
# training episode 436 of 1500 complete,  explore val = 0.112, episode reward = 145.0
# training episode 437 of 1500 complete,  explore val = 0.112, episode reward = 68.0
# training episode 438 of 1500 complete,  explore val = 0.111, episode reward = 148.0
# training episode 439 of 1500 complete,  explore val = 0.111, episode reward = 73.0
# training episode 440 of 1500 complete,  explore val = 0.11, episode reward = 158.0
# training episode 441 of 1500 complete,  explore val = 0.11, episode reward = 60.0
# training episode 442 of 1500 complete,  explore val = 0.109, episode reward = 153.0
# training episode 443 of 1500 complete,  explore val = 0.109, episode reward = 61.0
# training episode 444 of 1500 complete,  explore val = 0.108, episode reward = 132.0
# training episode 445 of 1500 complete,  explore val = 0.107, episode reward = 71.0
# training episode 446 of 1500 complete,  explore val = 0.107, episode reward = 145.0
# training episode 447 of 1500 complete,  explore val = 0.106, episode reward = 129.0
# training episode 448 of 1500 complete,  explore val = 0.106, episode reward = 129.0
# training episode 449 of 1500 complete,  explore val = 0.105, episode reward = 383.0
# training episode 450 of 1500 complete,  explore val = 0.105, episode reward = 113.0
# training episode 451 of 1500 complete,  explore val = 0.104, episode reward = 65.0
# training episode 452 of 1500 complete,  explore val = 0.104, episode reward = 121.0
# training episode 453 of 1500 complete,  explore val = 0.103, episode reward = 500.0
# training episode 454 of 1500 complete,  explore val = 0.103, episode reward = 95.0
# training episode 455 of 1500 complete,  explore val = 0.102, episode reward = 500.0
# training episode 456 of 1500 complete,  explore val = 0.102, episode reward = 104.0
# training episode 457 of 1500 complete,  explore val = 0.101, episode reward = 500.0
# training episode 458 of 1500 complete,  explore val = 0.101, episode reward = 74.0
# training episode 459 of 1500 complete,  explore val = 0.1, episode reward = 500.0
# training episode 460 of 1500 complete,  explore val = 0.1, episode reward = 61.0
# training episode 461 of 1500 complete,  explore val = 0.099, episode reward = 500.0
# training episode 462 of 1500 complete,  explore val = 0.099, episode reward = 38.0
# training episode 463 of 1500 complete,  explore val = 0.098, episode reward = 500.0
# training episode 464 of 1500 complete,  explore val = 0.098, episode reward = 31.0
# training episode 465 of 1500 complete,  explore val = 0.097, episode reward = 500.0
# training episode 466 of 1500 complete,  explore val = 0.097, episode reward = 18.0
# training episode 467 of 1500 complete,  explore val = 0.096, episode reward = 500.0
# training episode 468 of 1500 complete,  explore val = 0.096, episode reward = 20.0
# training episode 469 of 1500 complete,  explore val = 0.095, episode reward = 18.0
# training episode 470 of 1500 complete,  explore val = 0.095, episode reward = 34.0
# training episode 471 of 1500 complete,  explore val = 0.094, episode reward = 31.0
# training episode 472 of 1500 complete,  explore val = 0.094, episode reward = 8.0
# training episode 473 of 1500 complete,  explore val = 0.093, episode reward = 11.0
# training episode 474 of 1500 complete,  explore val = 0.093, episode reward = 9.0
# training episode 475 of 1500 complete,  explore val = 0.092, episode reward = 11.0
# training episode 476 of 1500 complete,  explore val = 0.092, episode reward = 500.0
# training episode 477 of 1500 complete,  explore val = 0.092, episode reward = 9.0
# training episode 478 of 1500 complete,  explore val = 0.091, episode reward = 366.0
# training episode 479 of 1500 complete,  explore val = 0.091, episode reward = 500.0
# training episode 480 of 1500 complete,  explore val = 0.09, episode reward = 161.0
# training episode 481 of 1500 complete,  explore val = 0.09, episode reward = 72.0
# training episode 482 of 1500 complete,  explore val = 0.089, episode reward = 130.0
# training episode 483 of 1500 complete,  explore val = 0.089, episode reward = 121.0
# training episode 484 of 1500 complete,  explore val = 0.088, episode reward = 22.0
# training episode 485 of 1500 complete,  explore val = 0.088, episode reward = 30.0
# training episode 486 of 1500 complete,  explore val = 0.088, episode reward = 108.0
# training episode 487 of 1500 complete,  explore val = 0.087, episode reward = 103.0
# training episode 488 of 1500 complete,  explore val = 0.087, episode reward = 111.0
# training episode 489 of 1500 complete,  explore val = 0.086, episode reward = 155.0
# training episode 490 of 1500 complete,  explore val = 0.086, episode reward = 182.0
# training episode 491 of 1500 complete,  explore val = 0.085, episode reward = 155.0
# training episode 492 of 1500 complete,  explore val = 0.085, episode reward = 491.0
# training episode 493 of 1500 complete,  explore val = 0.084, episode reward = 105.0
# training episode 494 of 1500 complete,  explore val = 0.084, episode reward = 184.0
# training episode 495 of 1500 complete,  explore val = 0.084, episode reward = 107.0
# training episode 496 of 1500 complete,  explore val = 0.083, episode reward = 228.0
# training episode 497 of 1500 complete,  explore val = 0.083, episode reward = 92.0
# training episode 498 of 1500 complete,  explore val = 0.082, episode reward = 216.0
# training episode 499 of 1500 complete,  explore val = 0.082, episode reward = 28.0
# training episode 500 of 1500 complete,  explore val = 0.082, episode reward = 168.0
# training episode 501 of 1500 complete,  explore val = 0.081, episode reward = 20.0
# training episode 502 of 1500 complete,  explore val = 0.081, episode reward = 193.0
# training episode 503 of 1500 complete,  explore val = 0.08, episode reward = 19.0
# training episode 504 of 1500 complete,  explore val = 0.08, episode reward = 170.0
# training episode 505 of 1500 complete,  explore val = 0.08, episode reward = 16.0
# training episode 506 of 1500 complete,  explore val = 0.079, episode reward = 229.0
# training episode 507 of 1500 complete,  explore val = 0.079, episode reward = 18.0
# training episode 508 of 1500 complete,  explore val = 0.078, episode reward = 500.0
# training episode 509 of 1500 complete,  explore val = 0.078, episode reward = 32.0
# training episode 510 of 1500 complete,  explore val = 0.078, episode reward = 237.0
# training episode 511 of 1500 complete,  explore val = 0.077, episode reward = 17.0
# training episode 512 of 1500 complete,  explore val = 0.077, episode reward = 266.0
# training episode 513 of 1500 complete,  explore val = 0.076, episode reward = 24.0
# training episode 514 of 1500 complete,  explore val = 0.076, episode reward = 200.0
# training episode 515 of 1500 complete,  explore val = 0.076, episode reward = 25.0
# training episode 516 of 1500 complete,  explore val = 0.075, episode reward = 184.0
# training episode 517 of 1500 complete,  explore val = 0.075, episode reward = 23.0
# training episode 518 of 1500 complete,  explore val = 0.075, episode reward = 195.0
# training episode 519 of 1500 complete,  explore val = 0.074, episode reward = 106.0
# training episode 520 of 1500 complete,  explore val = 0.074, episode reward = 311.0
# training episode 521 of 1500 complete,  explore val = 0.073, episode reward = 18.0
# training episode 522 of 1500 complete,  explore val = 0.073, episode reward = 159.0
# training episode 523 of 1500 complete,  explore val = 0.073, episode reward = 27.0
# training episode 524 of 1500 complete,  explore val = 0.072, episode reward = 184.0
# training episode 525 of 1500 complete,  explore val = 0.072, episode reward = 21.0
# training episode 526 of 1500 complete,  explore val = 0.072, episode reward = 176.0
# training episode 527 of 1500 complete,  explore val = 0.071, episode reward = 105.0
# training episode 528 of 1500 complete,  explore val = 0.071, episode reward = 500.0
# training episode 529 of 1500 complete,  explore val = 0.071, episode reward = 106.0
# training episode 530 of 1500 complete,  explore val = 0.07, episode reward = 500.0
# training episode 531 of 1500 complete,  explore val = 0.07, episode reward = 113.0
# training episode 532 of 1500 complete,  explore val = 0.069, episode reward = 290.0
# training episode 533 of 1500 complete,  explore val = 0.069, episode reward = 111.0
# training episode 534 of 1500 complete,  explore val = 0.069, episode reward = 150.0
# training episode 535 of 1500 complete,  explore val = 0.068, episode reward = 112.0
# training episode 536 of 1500 complete,  explore val = 0.068, episode reward = 226.0
# training episode 537 of 1500 complete,  explore val = 0.068, episode reward = 116.0
# training episode 538 of 1500 complete,  explore val = 0.067, episode reward = 184.0
# training episode 539 of 1500 complete,  explore val = 0.067, episode reward = 121.0
# training episode 540 of 1500 complete,  explore val = 0.067, episode reward = 107.0
# training episode 541 of 1500 complete,  explore val = 0.066, episode reward = 125.0
# training episode 542 of 1500 complete,  explore val = 0.066, episode reward = 86.0
# training episode 543 of 1500 complete,  explore val = 0.066, episode reward = 138.0
# training episode 544 of 1500 complete,  explore val = 0.065, episode reward = 85.0
# training episode 545 of 1500 complete,  explore val = 0.065, episode reward = 137.0
# training episode 546 of 1500 complete,  explore val = 0.065, episode reward = 77.0
# training episode 547 of 1500 complete,  explore val = 0.064, episode reward = 164.0
# training episode 548 of 1500 complete,  explore val = 0.064, episode reward = 69.0
# training episode 549 of 1500 complete,  explore val = 0.064, episode reward = 185.0
# training episode 550 of 1500 complete,  explore val = 0.063, episode reward = 31.0
# training episode 551 of 1500 complete,  explore val = 0.063, episode reward = 340.0
# training episode 552 of 1500 complete,  explore val = 0.063, episode reward = 19.0
# training episode 553 of 1500 complete,  explore val = 0.063, episode reward = 48.0
# training episode 554 of 1500 complete,  explore val = 0.062, episode reward = 26.0
# training episode 555 of 1500 complete,  explore val = 0.062, episode reward = 43.0
# training episode 556 of 1500 complete,  explore val = 0.062, episode reward = 41.0
# training episode 557 of 1500 complete,  explore val = 0.061, episode reward = 45.0
# training episode 558 of 1500 complete,  explore val = 0.061, episode reward = 43.0
# training episode 559 of 1500 complete,  explore val = 0.061, episode reward = 36.0
# training episode 560 of 1500 complete,  explore val = 0.06, episode reward = 47.0
# training episode 561 of 1500 complete,  explore val = 0.06, episode reward = 37.0
# training episode 562 of 1500 complete,  explore val = 0.06, episode reward = 49.0
# training episode 563 of 1500 complete,  explore val = 0.059, episode reward = 40.0
# training episode 564 of 1500 complete,  explore val = 0.059, episode reward = 45.0
# training episode 565 of 1500 complete,  explore val = 0.059, episode reward = 46.0
# training episode 566 of 1500 complete,  explore val = 0.059, episode reward = 66.0
# training episode 567 of 1500 complete,  explore val = 0.058, episode reward = 158.0
# training episode 568 of 1500 complete,  explore val = 0.058, episode reward = 36.0
# training episode 569 of 1500 complete,  explore val = 0.058, episode reward = 156.0
# training episode 570 of 1500 complete,  explore val = 0.057, episode reward = 35.0
# training episode 571 of 1500 complete,  explore val = 0.057, episode reward = 157.0
# training episode 572 of 1500 complete,  explore val = 0.057, episode reward = 25.0
# training episode 573 of 1500 complete,  explore val = 0.057, episode reward = 218.0
# training episode 574 of 1500 complete,  explore val = 0.056, episode reward = 28.0
# training episode 575 of 1500 complete,  explore val = 0.056, episode reward = 155.0
# training episode 576 of 1500 complete,  explore val = 0.056, episode reward = 28.0
# training episode 577 of 1500 complete,  explore val = 0.055, episode reward = 128.0
# ...
# training episode 1310 of 1500 complete,  explore val = 0.01, episode reward = 31.0
# training episode 1311 of 1500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 1312 of 1500 complete,  explore val = 0.01, episode reward = 39.0
# training episode 1313 of 1500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 1314 of 1500 complete,  explore val = 0.01, episode reward = 34.0
# training episode 1315 of 1500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 1316 of 1500 complete,  explore val = 0.01, episode reward = 36.0
# training episode 1317 of 1500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 1318 of 1500 complete,  explore val = 0.01, episode reward = 42.0
# training episode 1319 of 1500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 1320 of 1500 complete,  explore val = 0.01, episode reward = 38.0
# training episode 1321 of 1500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 1322 of 1500 complete,  explore val = 0.01, episode reward = 42.0
# training episode 1323 of 1500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 1324 of 1500 complete,  explore val = 0.01, episode reward = 36.0
# training episode 1325 of 1500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 1326 of 1500 complete,  explore val = 0.01, episode reward = 39.0
# training episode 1327 of 1500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 1328 of 1500 complete,  explore val = 0.01, episode reward = 36.0
# training episode 1329 of 1500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 1330 of 1500 complete,  explore val = 0.01, episode reward = 33.0
# training episode 1331 of 1500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 1332 of 1500 complete,  explore val = 0.01, episode reward = 30.0
# training episode 1333 of 1500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 1334 of 1500 complete,  explore val = 0.01, episode reward = 38.0
# training episode 1335 of 1500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 1336 of 1500 complete,  explore val = 0.01, episode reward = 44.0
# training episode 1337 of 1500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 1338 of 1500 complete,  explore val = 0.01, episode reward = 38.0
# training episode 1339 of 1500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 1340 of 1500 complete,  explore val = 0.01, episode reward = 35.0
# training episode 1341 of 1500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 1342 of 1500 complete,  explore val = 0.01, episode reward = 40.0
# training episode 1343 of 1500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 1344 of 1500 complete,  explore val = 0.01, episode reward = 37.0
# training episode 1345 of 1500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 1346 of 1500 complete,  explore val = 0.01, episode reward = 35.0
# training episode 1347 of 1500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 1348 of 1500 complete,  explore val = 0.01, episode reward = 43.0
# training episode 1349 of 1500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 1350 of 1500 complete,  explore val = 0.01, episode reward = 37.0
# training episode 1351 of 1500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 1352 of 1500 complete,  explore val = 0.01, episode reward = 40.0
# training episode 1353 of 1500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 1354 of 1500 complete,  explore val = 0.01, episode reward = 35.0
# training episode 1355 of 1500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 1356 of 1500 complete,  explore val = 0.01, episode reward = 39.0
# training episode 1357 of 1500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 1358 of 1500 complete,  explore val = 0.01, episode reward = 41.0
# training episode 1359 of 1500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 1360 of 1500 complete,  explore val = 0.01, episode reward = 38.0
# training episode 1361 of 1500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 1362 of 1500 complete,  explore val = 0.01, episode reward = 37.0
# training episode 1363 of 1500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 1364 of 1500 complete,  explore val = 0.01, episode reward = 48.0
# training episode 1365 of 1500 complete,  explore val = 0.01, episode reward = 191.0
# training episode 1366 of 1500 complete,  explore val = 0.01, episode reward = 43.0
# training episode 1367 of 1500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 1368 of 1500 complete,  explore val = 0.01, episode reward = 38.0
# training episode 1369 of 1500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 1370 of 1500 complete,  explore val = 0.01, episode reward = 44.0
# training episode 1371 of 1500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 1372 of 1500 complete,  explore val = 0.01, episode reward = 41.0
# training episode 1373 of 1500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 1374 of 1500 complete,  explore val = 0.01, episode reward = 41.0
# training episode 1375 of 1500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 1376 of 1500 complete,  explore val = 0.01, episode reward = 43.0
# training episode 1377 of 1500 complete,  explore val = 0.01, episode reward = 193.0
# training episode 1378 of 1500 complete,  explore val = 0.01, episode reward = 36.0
# training episode 1379 of 1500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 1380 of 1500 complete,  explore val = 0.01, episode reward = 42.0
# training episode 1381 of 1500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 1382 of 1500 complete,  explore val = 0.01, episode reward = 37.0
# training episode 1383 of 1500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 1384 of 1500 complete,  explore val = 0.01, episode reward = 47.0
# training episode 1385 of 1500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 1386 of 1500 complete,  explore val = 0.01, episode reward = 53.0
# training episode 1387 of 1500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 1388 of 1500 complete,  explore val = 0.01, episode reward = 44.0
# training episode 1389 of 1500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 1390 of 1500 complete,  explore val = 0.01, episode reward = 48.0
# training episode 1391 of 1500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 1392 of 1500 complete,  explore val = 0.01, episode reward = 45.0
# training episode 1393 of 1500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 1394 of 1500 complete,  explore val = 0.01, episode reward = 55.0
# training episode 1395 of 1500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 1396 of 1500 complete,  explore val = 0.01, episode reward = 50.0
# training episode 1397 of 1500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 1398 of 1500 complete,  explore val = 0.01, episode reward = 67.0
# training episode 1399 of 1500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 1400 of 1500 complete,  explore val = 0.01, episode reward = 42.0
# training episode 1401 of 1500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 1402 of 1500 complete,  explore val = 0.01, episode reward = 53.0
# training episode 1403 of 1500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 1404 of 1500 complete,  explore val = 0.01, episode reward = 44.0
# training episode 1405 of 1500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 1406 of 1500 complete,  explore val = 0.01, episode reward = 51.0
# training episode 1407 of 1500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 1408 of 1500 complete,  explore val = 0.01, episode reward = 53.0
# training episode 1409 of 1500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 1410 of 1500 complete,  explore val = 0.01, episode reward = 44.0
# training episode 1411 of 1500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 1412 of 1500 complete,  explore val = 0.01, episode reward = 49.0
# training episode 1413 of 1500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 1414 of 1500 complete,  explore val = 0.01, episode reward = 59.0
# training episode 1415 of 1500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 1416 of 1500 complete,  explore val = 0.01, episode reward = 52.0
# training episode 1417 of 1500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 1418 of 1500 complete,  explore val = 0.01, episode reward = 46.0
# training episode 1419 of 1500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 1420 of 1500 complete,  explore val = 0.01, episode reward = 48.0
# training episode 1421 of 1500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 1422 of 1500 complete,  explore val = 0.01, episode reward = 51.0
# training episode 1423 of 1500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 1424 of 1500 complete,  explore val = 0.01, episode reward = 57.0
# training episode 1425 of 1500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 1426 of 1500 complete,  explore val = 0.01, episode reward = 51.0
# training episode 1427 of 1500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 1428 of 1500 complete,  explore val = 0.01, episode reward = 47.0
# training episode 1429 of 1500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 1430 of 1500 complete,  explore val = 0.01, episode reward = 51.0
# training episode 1431 of 1500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 1432 of 1500 complete,  explore val = 0.01, episode reward = 63.0
# training episode 1433 of 1500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 1434 of 1500 complete,  explore val = 0.01, episode reward = 51.0
# training episode 1435 of 1500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 1436 of 1500 complete,  explore val = 0.01, episode reward = 67.0
# training episode 1437 of 1500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 1438 of 1500 complete,  explore val = 0.01, episode reward = 43.0
# training episode 1439 of 1500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 1440 of 1500 complete,  explore val = 0.01, episode reward = 53.0
# training episode 1441 of 1500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 1442 of 1500 complete,  explore val = 0.01, episode reward = 45.0
# training episode 1443 of 1500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 1444 of 1500 complete,  explore val = 0.01, episode reward = 55.0
# training episode 1445 of 1500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 1446 of 1500 complete,  explore val = 0.01, episode reward = 55.0
# training episode 1447 of 1500 complete,  explore val = 0.01, episode reward = 161.0
# training episode 1448 of 1500 complete,  explore val = 0.01, episode reward = 45.0
# training episode 1449 of 1500 complete,  explore val = 0.01, episode reward = 142.0
# training episode 1450 of 1500 complete,  explore val = 0.01, episode reward = 41.0
# training episode 1451 of 1500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 1452 of 1500 complete,  explore val = 0.01, episode reward = 27.0
# training episode 1453 of 1500 complete,  explore val = 0.01, episode reward = 88.0
# training episode 1454 of 1500 complete,  explore val = 0.01, episode reward = 37.0
# training episode 1455 of 1500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 1456 of 1500 complete,  explore val = 0.01, episode reward = 39.0
# training episode 1457 of 1500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 1458 of 1500 complete,  explore val = 0.01, episode reward = 37.0
# training episode 1459 of 1500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 1460 of 1500 complete,  explore val = 0.01, episode reward = 49.0
# training episode 1461 of 1500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 1462 of 1500 complete,  explore val = 0.01, episode reward = 57.0
# training episode 1463 of 1500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 1464 of 1500 complete,  explore val = 0.01, episode reward = 39.0
# training episode 1465 of 1500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 1466 of 1500 complete,  explore val = 0.01, episode reward = 57.0
# training episode 1467 of 1500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 1468 of 1500 complete,  explore val = 0.01, episode reward = 41.0
# training episode 1469 of 1500 complete,  explore val = 0.01, episode reward = 138.0
# training episode 1470 of 1500 complete,  explore val = 0.01, episode reward = 55.0
# training episode 1471 of 1500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 1472 of 1500 complete,  explore val = 0.01, episode reward = 61.0
# training episode 1473 of 1500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 1474 of 1500 complete,  explore val = 0.01, episode reward = 73.0
# training episode 1475 of 1500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 1476 of 1500 complete,  explore val = 0.01, episode reward = 53.0
# training episode 1477 of 1500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 1478 of 1500 complete,  explore val = 0.01, episode reward = 49.0
# training episode 1479 of 1500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 1480 of 1500 complete,  explore val = 0.01, episode reward = 53.0
# training episode 1481 of 1500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 1482 of 1500 complete,  explore val = 0.01, episode reward = 65.0
# training episode 1483 of 1500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 1484 of 1500 complete,  explore val = 0.01, episode reward = 59.0
# training episode 1485 of 1500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 1486 of 1500 complete,  explore val = 0.01, episode reward = 67.0
# training episode 1487 of 1500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 1488 of 1500 complete,  explore val = 0.01, episode reward = 57.0
# training episode 1489 of 1500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 1490 of 1500 complete,  explore val = 0.01, episode reward = 76.0
# training episode 1491 of 1500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 1492 of 1500 complete,  explore val = 0.01, episode reward = 82.0
# training episode 1493 of 1500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 1494 of 1500 complete,  explore val = 0.01, episode reward = 95.0
# training episode 1495 of 1500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 1496 of 1500 complete,  explore val = 0.01, episode reward = 85.0
# training episode 1497 of 1500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 1498 of 1500 complete,  explore val = 0.01, episode reward = 51.0
# training episode 1499 of 1500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 1500 of 1500 complete,  explore val = 0.01, episode reward = 55.0
# q-learning algorithm complete

# %% [markdown]
# # plot total episode reward history

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_reward_history(logname,**kwargs):
    # load in total episode reward history
    data = np.loadtxt(logname)
    ave = [data[v] for v in range(100)]
    
    for i in range(0,np.size(data)-100):
        m = np.mean(data[i:i+100])
        ave.append(m)
    
    # create figure
    fig = plt.figure(figsize = (12,8))
    ax1 = fig.add_subplot(2,1,1)
    ax2 = fig.add_subplot(2,1,2)

    # plot total reward history
    start = 0
    if 'start' in kwargs:
        start = kwargs['start']
    ax1.plot(data[start:])
    ax1.set_xlabel('episode',labelpad = 8,fontsize = 13)
    ax1.set_ylabel('total reward',fontsize = 13)
    
    ax2.plot(ave[start:],linewidth=3)
    ax2.set_xlabel('episode',labelpad = 8,fontsize = 13)
    ax2.set_ylabel('ave total reward',fontsize=13)
    plt.show()

# %%
reward_logname = 'reward_logs/' + savename + '.txt'
plot_reward_history(reward_logname)

# %% [markdown]
# # produce animation of validation run

# %%
# load in weights
infile = demo.weight_name
with open(infile, 'rb') as in_strm:
    datastruct = pickle.load(in_strm)

# %%
len(datastruct)
# Out:
# 1500
